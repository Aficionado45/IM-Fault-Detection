# %% [markdown]
# ### Testing accuracy of RF classifier by providing training data of 20Hz, 30Hz and 40Hz defects and testing out it's accuracy on different speed readings of 10Hz, 15Hz, 20Hz, 25HZ, 30Hz and 35Hz.
#
# ### Training Dataset consists of 10000 rows for each fault and testing data consists of 20000 rows for each fault. Mix data consists of 200 rows data for each fault in all rotational speeds.

# %%
import pandas as pd

data_20=pd.read_csv(r'D:\Acads\BTP\Train\Train20Hz.csv')
data_30=pd.read_csv(r'D:\Acads\BTP\Train\Train30Hz.csv')
data_40=pd.read_csv(r'D:\Acads\BTP\Train\Train40Hz.csv')

# %%
data_20.head
# Out:
# <bound method NDFrame.head of         X_Value  Acceleration  Acceleration_0  Acceleration_1   Voltage  \
# 0       0.00000      1.708963       22.936699        0.418647  0.062727
# 1       0.00005      0.397558       20.744087       -2.443510  0.058105
# 2       0.00010      0.245741       19.886220       -4.793004  0.065566
# 3       0.00015     -0.492077       16.847528       -7.492809  0.060839
# 4       0.00020      1.393773       15.511186       -5.217568  0.068609
# ...         ...           ...             ...             ...       ...
# 100239  1.01385     -2.401899       -2.835274       -2.798354  0.168155
# 100240  1.01390      1.870737       -1.357366        0.724601  0.170059
# 100241  1.01395      1.843078       -2.764307        1.164236  0.166506
# 100242  1.01400      5.318520        0.023913        4.574955  0.167842
# 100243  1.01405      5.640224       -0.904798        2.451036  0.162821
#
#         Voltage_0  Voltage_1  Voltage_2  Voltage_3  Identity
# 0        0.152310  -0.216667   0.000854  -0.170166         1
# 1        0.148238  -0.208466   0.000819  -0.034754         1
# 2        0.150867  -0.217372   0.000753  -0.066492         1
# 3        0.147171  -0.208646   0.000790   0.055139         1
# 4        0.149121  -0.217855   0.000831   0.023973         1
# ...           ...        ...        ...        ...       ...
# 100239  -0.220463   0.052978  -0.000590   0.114022         4
# 100240  -0.227182   0.056192  -0.000541  -0.009250         4
# 100241  -0.220024   0.053968  -0.000572  -0.098004         4
# 100242  -0.227625   0.058899  -0.000545   0.055944         4
# 100243  -0.221341   0.058433  -0.000567   0.050418         4
#
# [100244 rows x 10 columns]>

# %%
data_30.head
# Out:
# <bound method NDFrame.head of         X_Value  Acceleration  Acceleration_0  Acceleration_1   Voltage  \
# 0      0.000000    -11.367953      -11.637524        6.021533 -0.211798
# 1      0.000050    -12.166375       -9.140292        3.120780 -0.217642
# 2      0.000100     -8.550057       -4.918858        0.881439 -0.211531
# 3      0.000150     -7.510203       -1.977898       -0.244971 -0.217031
# 4      0.000200     -9.059351        0.536890        3.866246 -0.210774
# ...         ...           ...             ...             ...       ...
# 99948  0.999350      6.308956       -7.804564        2.868125 -0.231882
# 99949  0.999400      3.970360       -6.623541        1.938864 -0.229132
# 99950  0.999450      1.442453       -4.509385        2.251926 -0.233108
# 99951  0.999500     -0.867132       -3.078502        0.568868 -0.229825
# 99952  0.999528     -0.404975       -0.450460       -0.560514  0.001299
#
#        Voltage_0  Voltage_1  Voltage_2  Voltage_3  Identity
# 0       0.124550   0.087489  -0.000407  -0.151828         1
# 1       0.134079   0.082623  -0.000408  -0.034398         1
# 2       0.126679   0.084210  -0.000362  -0.156903         1
# 3       0.137591   0.078589  -0.000408   0.131691         1
# 4       0.130023   0.080551  -0.000396  -0.214258         1
# ...          ...        ...        ...        ...       ...
# 99948   0.122237   0.109242   0.001851  -0.073762         4
# 99949   0.120721   0.107070   0.001578   0.034238         4
# 99950   0.126991   0.106174   0.001714  -0.025075         4
# 99951   0.125186   0.103691   0.001626   0.049136         4
# 99952  -0.007117   0.005242  -0.000015   0.000366         4
#
# [99953 rows x 10 columns]>

# %%
#shuffling
data_20=data_20.sample(frac=0.5)
data_30=data_30.sample(frac=0.5)
data_40=data_40.sample(frac=1)

# %%
data_20.head
# Out:
# <bound method NDFrame.head of        X_Value  Acceleration  Acceleration_0  Acceleration_1   Voltage  \
# 59634  0.98270     -0.485930        0.588825       -0.717198 -0.205831
# 20680  0.03450     -2.003118       -0.689441        0.209122 -0.048939
# 38857  0.94335      3.915657       -1.834982       -2.203720  0.202474
# 19806  0.99030     -7.134656      -20.964168       13.143656 -0.117265
# 41890  0.09550     -1.727880        0.376784       -0.138003  0.115214
# ...        ...           ...             ...             ...       ...
# 10825  0.54125     -4.006118      -18.228743        6.958145 -0.134763
# 29066  0.45380      3.503476        2.812501       -1.831232  0.155894
# 69727  0.48780     -1.160318       -2.767991       -2.858883  0.228189
# 31811  0.59105      4.199991        4.247191        0.816131  0.158248
# 90794  0.54160     -1.015139       -0.139384       -0.504732 -0.089951
#
#        Voltage_0  Voltage_1  Voltage_2  Voltage_3  Identity
# 59634   0.101518   0.104379   0.000120   0.052007         0
# 20680   0.212942  -0.163879  -0.000292   0.102279         2
# 38857  -0.023089  -0.179832  -0.000550   0.086621         2
# 19806   0.209209  -0.090012   0.000748   0.064539         1
# 41890  -0.229953   0.116102   0.000012   0.021901         0
# ...          ...        ...        ...        ...       ...
# 10825   0.214385  -0.078357  -0.000291  -0.022373         1
# 29066  -0.198477   0.043078  -0.000332   0.049410         2
# 69727  -0.104618  -0.124282  -0.001204  -0.026991         3
# 31811   0.064341  -0.226348  -0.000314  -0.003305         2
# 90794   0.224813  -0.135946  -0.000642  -0.017703         4
#
# [50122 rows x 10 columns]>

# %%
data_30.head
# Out:
# <bound method NDFrame.head of        X_Value  Acceleration  Acceleration_0  Acceleration_1   Voltage  \
# 60852  0.04410     -2.041225       -5.486839       -1.864437 -0.128750
# 36779  0.83945     -3.703959       -7.607748       -5.376242 -0.194124
# 60303  0.01665     -2.116827       -3.981183       -2.513841 -0.228808
# 14537  0.72685     -6.284357      -19.051371       -1.334621 -0.141765
# 67196  0.36130      0.789209        4.090646       -0.206742  0.151947
# ...        ...           ...             ...             ...       ...
# 85122  0.25805     -1.839745        4.100836       -0.431828  0.108612
# 6861   0.34305     -2.971550      -11.101341       -0.354511  0.116477
# 54782  0.74010      7.225145        1.032063       -4.766906 -0.095526
# 91274  0.56565      1.517931       -0.156206        3.390957 -0.190247
# 98817  0.94280     10.632116       -8.850409        2.814090  0.038429
#
#        Voltage_0  Voltage_1  Voltage_2  Voltage_3  Identity
# 60852  -0.117248   0.244246   0.002552  -0.051959         3
# 36779  -0.016364   0.210760   0.001299  -0.229263         2
# 60303   0.112169   0.116580  -0.001344  -0.032077         3
# 14537  -0.079272   0.219830  -0.000309  -0.093536         1
# 67196   0.084176  -0.236388  -0.001239   0.002935         3
# ...          ...        ...        ...        ...       ...
# 85122  -0.221515   0.112565  -0.000733  -0.202272         4
# 6861    0.109073  -0.224689  -0.000340   0.106697         1
# 54782   0.245301  -0.149983   0.000128   0.272077         0
# 91274   0.000076   0.189746  -0.000745  -0.119162         4
# 98817   0.169295  -0.207640  -0.000625  -0.040960         4
#
# [49976 rows x 10 columns]>

# %%
import sklearn as sk
data_40.head
# Out:
# <bound method NDFrame.head of         X_Value  Acceleration  Acceleration_0  Acceleration_1   Voltage  \
# 4371    0.21855    -12.246894        5.607843        6.480159  0.039768
# 15047   0.25235     -1.691247       -3.282686        3.946380 -0.193251
# 20467   0.02335      0.829161        0.060134       -1.319428  0.219187
# 33860   4.49300      1.376071       -8.250380       -1.268824  0.134400
# 6114    0.30570      5.649320       -1.844436        1.765976 -0.049300
# ...         ...           ...             ...             ...       ...
# 9693    0.48465      3.732861       15.904452       -8.633555  0.197477
# 29789  29.98945     -0.568415       -3.583620       -1.479941  0.153220
# 20058   0.00290      4.720226        4.332277       12.912321  0.212272
# 32483   4.42415     -1.356881        1.035255        9.532726 -0.162984
# 27063   3.05315     -6.649701       -5.447304       -6.385514  0.171935
#
#        Voltage_0  Voltage_1  Voltage_2  Voltage_3  Comment
# 4371   -0.219611   0.181209  -0.000343  -0.374631        1
# 15047  -0.024697   0.217477  -0.000434  -0.168800        2
# 20467   0.012064  -0.230779   0.000106   0.061880        0
# 33860  -0.233626   0.099527  -0.001047   0.007529        3
# 6114    0.212558  -0.166817   0.000908   0.083488        1
# ...          ...        ...        ...        ...      ...
# 9693    0.005390  -0.204535   0.000904  -0.180711        1
# 29789   0.088770  -0.243798   0.000068   0.265634        0
# 20058  -0.209531  -0.003071   0.000148   0.025047        0
# 32483  -0.051730   0.212568  -0.000984   0.292939        3
# 27063  -0.240715   0.069775   0.000115  -0.532811        0
#
# [50000 rows x 10 columns]>

# %%
# X and y for training 20Hz dataset
dataset_20=data_20.values
X_20= dataset_20[:,0:9]
print(X_20)

y_20=dataset_20[:,9]
print(y_20)
# Out:
# [[ 9.827000e-01 -4.859300e-01  5.888250e-01 ...  1.043790e-01
#    1.200000e-04  5.200700e-02]
#  [ 3.450000e-02 -2.003118e+00 -6.894410e-01 ... -1.638790e-01
#   -2.920000e-04  1.022790e-01]
#  [ 9.433500e-01  3.915657e+00 -1.834982e+00 ... -1.798320e-01
#   -5.500000e-04  8.662100e-02]
#  ...
#  [ 4.878000e-01 -1.160318e+00 -2.767991e+00 ... -1.242820e-01
#   -1.204000e-03 -2.699100e-02]
#  [ 5.910500e-01  4.199991e+00  4.247191e+00 ... -2.263480e-01
#   -3.140000e-04 -3.305000e-03]
#  [ 5.416000e-01 -1.015139e+00 -1.393840e-01 ... -1.359460e-01
#   -6.420000e-04 -1.770300e-02]]
# [0. 2. 2. ... 3. 2. 4.]

# %%
# X and y for training 30Hz dataset
dataset_30=data_30.values
X_30= dataset_30[:,0:9]
print(X_30)

y_30=dataset_30[:,9]
print(y_30)
# Out:
# [[ 4.4100000e-02 -2.0412250e+00 -5.4868390e+00 ...  2.4424600e-01
#    2.5520000e-03 -5.1959000e-02]
#  [ 8.3945000e-01 -3.7039590e+00 -7.6077480e+00 ...  2.1076000e-01
#    1.2990000e-03 -2.2926300e-01]
#  [ 1.6650000e-02 -2.1168270e+00 -3.9811830e+00 ...  1.1658000e-01
#   -1.3440000e-03 -3.2077000e-02]
#  ...
#  [ 7.4010000e-01  7.2251450e+00  1.0320630e+00 ... -1.4998300e-01
#    1.2800000e-04  2.7207700e-01]
#  [ 5.6565000e-01  1.5179310e+00 -1.5620600e-01 ...  1.8974600e-01
#   -7.4500000e-04 -1.1916200e-01]
#  [ 9.4280000e-01  1.0632116e+01 -8.8504090e+00 ... -2.0764000e-01
#   -6.2500000e-04 -4.0960000e-02]]
# [3. 2. 3. ... 0. 4. 4.]

# %%
# X and y for training 30Hz dataset
dataset_40=data_40.values
X_40= dataset_40[:,0:9]
print(X_40)

y_40=dataset_40[:,9]
print(y_40)
# Out:
# [[ 2.1855000e-01 -1.2246894e+01  5.6078430e+00 ...  1.8120900e-01
#   -3.4300000e-04 -3.7463100e-01]
#  [ 2.5235000e-01 -1.6912470e+00 -3.2826860e+00 ...  2.1747700e-01
#   -4.3400000e-04 -1.6880000e-01]
#  [ 2.3350000e-02  8.2916100e-01  6.0134000e-02 ... -2.3077900e-01
#    1.0600000e-04  6.1880000e-02]
#  ...
#  [ 2.9000000e-03  4.7202260e+00  4.3322770e+00 ... -3.0710000e-03
#    1.4800000e-04  2.5047000e-02]
#  [ 4.4241500e+00 -1.3568810e+00  1.0352550e+00 ...  2.1256800e-01
#   -9.8400000e-04  2.9293900e-01]
#  [ 3.0531500e+00 -6.6497010e+00 -5.4473040e+00 ...  6.9775000e-02
#    1.1500000e-04 -5.3281100e-01]]
# [1. 2. 0. ... 0. 3. 0.]

# %%
#Training random forest classifier

from sklearn.ensemble import RandomForestClassifier
rf_20 = RandomForestClassifier(n_estimators = 1000, random_state = 42)
rf_20.fit(X_20, y_20);

# %%
#Training random forest Classifier

from sklearn.ensemble import RandomForestClassifier
rf_30 = RandomForestClassifier(n_estimators = 1000, random_state = 42)
rf_30.fit(X_30, y_30);

# %%
#Training random forest Classifier

from sklearn.ensemble import RandomForestClassifier
rf_40 = RandomForestClassifier(n_estimators = 1000, random_state = 42)
rf_40.fit(X_40, y_40);

# %%
test_15= pd.read_csv(r'D:\Acads\BTP\Train\Train15Hz.csv')
test_15.head
# Out:
# <bound method NDFrame.head of        X_Value  Acceleration  Acceleration_0  Acceleration_1   Voltage  \
# 0      0.00000     -1.525662       -2.224441       -0.555582 -0.021681
# 1      0.00005     -1.392776       -2.294180       -0.066691 -0.019098
# 2      0.00010     -0.174552       -1.000812        0.584061 -0.019375
# 3      0.00015     -0.383162       -1.101492        1.278678 -0.016724
# 4      0.00020      1.119027        0.109123        2.087247 -0.017092
# ...        ...           ...             ...             ...       ...
# 99949  0.99925     -0.086289        1.216725       -1.050722 -0.210134
# 99950  0.99930      0.034796        1.739032       -1.707600 -0.214406
# 99951  0.99935     -0.306700        1.865864       -2.614070 -0.209294
# 99952  0.99940     -0.349602        2.158573       -2.790634 -0.213611
# 99953  0.99945     -0.223231        2.109338       -2.928357 -0.208421
#
#        Voltage_0  Voltage_1  Voltage_2  Voltage_3  Identity
# 0       0.204297  -0.183614  -0.000185  -0.007744         1
# 1       0.203327  -0.187030  -0.000199  -0.015469         1
# 2       0.202721  -0.184704  -0.000153  -0.033848         1
# 3       0.202069  -0.188086  -0.000211   0.073223         1
# 4       0.201569  -0.185779  -0.000217   0.003786         1
# ...          ...        ...        ...        ...       ...
# 99949   0.182882   0.026613  -0.000414  -0.075549         4
# 99950   0.191532   0.022294  -0.000392   0.004331         4
# 99951   0.184456   0.024698  -0.000431   0.021859         4
# 99952   0.192194   0.020143  -0.000452  -0.079773         4
# 99953   0.184310   0.022566  -0.000389  -0.203361         4
#
# [99954 rows x 10 columns]>

# %%
#shuffling train data
test_15= test_15.sample(frac=1)
test_15.head
# Out:
# <bound method NDFrame.head of        X_Value  Acceleration  Acceleration_0  Acceleration_1   Voltage  \
# 19063  0.95315     -2.593422      -10.050955       -0.149398  0.097508
# 78080  0.90540     -0.521580       -0.788279       -0.645028 -0.189361
# 77550  0.87890     -0.429875        1.409121       -0.473732  0.224377
# 16022  0.80110     -1.691739       -2.231808       -1.763106  0.138201
# 18624  0.93120      5.178750       -1.091178       -1.183298  0.106479
# ...        ...           ...             ...             ...       ...
# 38661  0.93350      0.970160        0.420003       -1.289776  0.000308
# 37607  0.88080     -2.141658       -4.871218       -1.877915  0.204580
# 42954  0.14865     -0.519121        0.523015       -0.790838  0.224382
# 3852   0.19260      0.549252      -12.141045        2.499190 -0.113152
# 96677  0.83565     -3.601683       -3.667725       -2.412755  0.206820
#
#        Voltage_0  Voltage_1  Voltage_2  Voltage_3  Identity
# 19063  -0.205614   0.107733  -0.000398   0.032082         1
# 78080  -0.026279   0.215976  -0.001096   0.002587         3
# 77550  -0.092541  -0.131435   0.002826  -0.060625         3
# 16022   0.060273  -0.201213   0.000639   0.037110         1
# 18624   0.097503  -0.206668   0.000800  -0.012490         1
# ...          ...        ...        ...        ...       ...
# 38661   0.196544  -0.197287   0.001112  -0.077246         2
# 37607  -0.049089  -0.156041  -0.000551  -0.034693         2
# 42954  -0.062325  -0.164205   0.000371  -0.156010         0
# 3852    0.201116  -0.090650  -0.000318  -0.087306         1
# 96677  -0.187063  -0.019138   0.001012   0.040986         4
#
# [99954 rows x 10 columns]>

# %%
#Assigning X and Y parameter for testing 15Hz 

dataset_test_15 = test_15.values
X_test_15 = dataset_test_15[:,0:9]
print(X_test_15)

y_test_15= dataset_test_15[:,9]
print(y_test_15)
# Out:
# [[ 9.5315000e-01 -2.5934220e+00 -1.0050955e+01 ...  1.0773300e-01
#   -3.9800000e-04  3.2082000e-02]
#  [ 9.0540000e-01 -5.2158000e-01 -7.8827900e-01 ...  2.1597600e-01
#   -1.0960000e-03  2.5870000e-03]
#  [ 8.7890000e-01 -4.2987500e-01  1.4091210e+00 ... -1.3143500e-01
#    2.8260000e-03 -6.0625000e-02]
#  ...
#  [ 1.4865000e-01 -5.1912100e-01  5.2301500e-01 ... -1.6420500e-01
#    3.7100000e-04 -1.5601000e-01]
#  [ 1.9260000e-01  5.4925200e-01 -1.2141045e+01 ... -9.0650000e-02
#   -3.1800000e-04 -8.7306000e-02]
#  [ 8.3565000e-01 -3.6016830e+00 -3.6677250e+00 ... -1.9138000e-02
#    1.0120000e-03  4.0986000e-02]]
# [1. 3. 3. ... 0. 1. 4.]

# %%
#20Hz testing 
test_20= pd.read_csv(r'D:\Acads\BTP\Train\Train20Hz.csv')
test_20.head
test_20= test_20.sample(frac=1)
test_20.head
# Out:
# <bound method NDFrame.head of        X_Value  Acceleration  Acceleration_0  Acceleration_1   Voltage  \
# 33213  0.66115      1.283998        0.748317       -2.018333 -0.044147
# 8007   0.40035     -0.997929       13.738974       -2.075800  0.095613
# 85486  0.27620      3.220248       -5.627668        2.038603 -0.151908
# 88357  0.41975     -5.704502        3.557533        0.704752 -0.017648
# 89584  0.48110      1.163405       -4.654634        1.852114 -0.226910
# ...        ...           ...             ...             ...       ...
# 63974  0.20015     -0.224338       -3.264023        0.123474  0.027998
# 50658  0.53390     -1.986030       -3.271144       -2.166717 -0.015556
# 87375  0.37065      2.067546        2.580938       -0.715605 -0.023306
# 28883  0.44465     -3.562714       -1.784151       -0.643803  0.203045
# 75415  0.77220     -1.297875       -1.737494       -3.056645 -0.073852
#
#        Voltage_0  Voltage_1  Voltage_2  Voltage_3  Identity
# 33213  -0.172199   0.216765  -0.000200   0.032348         2
# 8007    0.111230  -0.208203  -0.000246  -0.035642         1
# 85486  -0.067286   0.217487  -0.000729  -0.008986         4
# 88357  -0.185562   0.203760   0.001492  -0.036249         4
# 89584   0.083373   0.142636  -0.000762   0.123743         4
# ...          ...        ...        ...        ...       ...
# 63974  -0.229436   0.200939  -0.000662   0.065345         3
# 50658   0.201286  -0.186298   0.000094  -0.000212         0
# 87375  -0.181824   0.204856   0.001423   0.053092         4
# 28883  -0.025140  -0.178941  -0.000393   0.058450         2
# 75415   0.227594  -0.154973  -0.000756  -0.043698         3
#
# [100244 rows x 10 columns]>

# %%
#Assigning X and Y parameter for testing 20Hz

dataset_test_20 = test_20.values
X_test_20 = dataset_test_20[:,0:9]
print(X_test_20)

y_test_20= dataset_test_20[:,9]
print(y_test_20)
# Out:
# [[ 6.6115000e-01  1.2839980e+00  7.4831700e-01 ...  2.1676500e-01
#   -2.0000000e-04  3.2348000e-02]
#  [ 4.0035000e-01 -9.9792900e-01  1.3738974e+01 ... -2.0820300e-01
#   -2.4600000e-04 -3.5642000e-02]
#  [ 2.7620000e-01  3.2202480e+00 -5.6276680e+00 ...  2.1748700e-01
#   -7.2900000e-04 -8.9860000e-03]
#  ...
#  [ 3.7065000e-01  2.0675460e+00  2.5809380e+00 ...  2.0485600e-01
#    1.4230000e-03  5.3092000e-02]
#  [ 4.4465000e-01 -3.5627140e+00 -1.7841510e+00 ... -1.7894100e-01
#   -3.9300000e-04  5.8450000e-02]
#  [ 7.7220000e-01 -1.2978750e+00 -1.7374940e+00 ... -1.5497300e-01
#   -7.5600000e-04 -4.3698000e-02]]
# [2. 1. 4. ... 4. 2. 3.]

# %%
# 30Hz testing
test_30= pd.read_csv(r'D:\Acads\BTP\Train\Train30Hz.csv')
test_30.head
test_30= test_30.sample(frac=1)
test_30.head
# Out:
# <bound method NDFrame.head of        X_Value  Acceleration  Acceleration_0  Acceleration_1   Voltage  \
# 64800  0.24150      3.826164        5.611403       -0.297535 -0.030985
# 24535  0.22725      8.600717        2.520284       -4.956458  0.212981
# 97131  0.85850     -0.906716        7.601797        1.900513 -0.008851
# 69603  0.48165     -2.655131       -5.522568        1.529373 -0.238595
# 38236  0.91230     -5.260976      -12.083707       -1.396131 -0.171348
# ...        ...           ...             ...             ...       ...
# 58062  0.90410     -4.057257       -0.394646        2.425672 -0.183647
# 4957   0.24785    -17.684893      -23.149781        5.176695  0.224570
# 96518  0.82785      0.993640       -2.030694       -0.894742 -0.109565
# 38816  0.94130     -2.644191       -7.365134       -3.370442 -0.246657
# 42843  0.14315      0.048440        0.166829       -0.560728  0.028943
#
#        Voltage_0  Voltage_1  Voltage_2  Voltage_3  Identity
# 64800  -0.213086   0.242250  -0.000762   0.237235         3
# 24535  -0.070396  -0.142731   0.001116   0.134933         2
# 97131  -0.194491   0.203536  -0.000462   0.064377         4
# 69603   0.061953   0.174277  -0.000867  -0.006045         3
# 38236   0.214061  -0.045163   0.001177  -0.064800         2
# ...          ...        ...        ...        ...       ...
# 58062   0.224442  -0.041905   0.000103   0.084119         0
# 4957   -0.091736  -0.132462  -0.000263  -0.157045         1
# 96518  -0.110869   0.218439  -0.000452  -0.159349         4
# 38816   0.114023   0.131153  -0.000366  -0.057788         2
# 42843   0.196555  -0.226273   0.000094   0.232123         0
#
# [99953 rows x 10 columns]>

# %%
#Assigning X and Y parameter for testing 30Hz

dataset_test_30 = test_30.values
X_test_30 = dataset_test_30[:,0:9]
print(X_test_30)

y_test_30= dataset_test_30[:,9]
print(y_test_30)
# Out:
# [[ 2.415000e-01  3.826164e+00  5.611403e+00 ...  2.422500e-01
#   -7.620000e-04  2.372350e-01]
#  [ 2.272500e-01  8.600717e+00  2.520284e+00 ... -1.427310e-01
#    1.116000e-03  1.349330e-01]
#  [ 8.585000e-01 -9.067160e-01  7.601797e+00 ...  2.035360e-01
#   -4.620000e-04  6.437700e-02]
#  ...
#  [ 8.278500e-01  9.936400e-01 -2.030694e+00 ...  2.184390e-01
#   -4.520000e-04 -1.593490e-01]
#  [ 9.413000e-01 -2.644191e+00 -7.365134e+00 ...  1.311530e-01
#   -3.660000e-04 -5.778800e-02]
#  [ 1.431500e-01  4.844000e-02  1.668290e-01 ... -2.262730e-01
#    9.444542e-05  2.321230e-01]]
# [3. 2. 4. ... 4. 2. 0.]

# %%
# 40Hz testing
test_40= pd.read_csv(r'D:\Acads\BTP\Train\Train40Hz.csv')
test_40.head
test_40= test_40.sample(frac=1)
test_40.head
# Out:
# <bound method NDFrame.head of         X_Value  Acceleration  Acceleration_0  Acceleration_1   Voltage  \
# 21128   0.05640      2.612366       -8.866247        2.753561  0.018387
# 45893   5.09465      6.031629       -6.319045       -0.130651  0.032650
# 40800   0.14000     -3.388524       -0.058718       -6.414063 -0.214142
# 16855   0.34275    -10.031841       -4.525346        1.950505  0.217635
# 9461    0.47305      8.634277      -12.592140      -13.022178 -0.225671
# ...         ...           ...             ...             ...       ...
# 16420   0.32100    -19.081240      -15.465815       -1.115418  0.141275
# 38567  25.22835     -0.986373        3.363171       -3.187139 -0.150770
# 17120   0.35600     -2.792319       -2.122779       -0.910181 -0.226147
# 27851   3.09255      6.863611       -5.009591       -3.687670 -0.052716
# 21952   0.09760     -3.856391       -2.906978       -3.956130  0.185013
#
#        Voltage_0  Voltage_1  Voltage_2  Voltage_3  Comment
# 21128  -0.238746   0.220572   0.000093   0.215216        0
# 45893   0.173369  -0.208376  -0.000447   0.013820        4
# 40800   0.173518   0.038832  -0.000540   0.100936        4
# 16855  -0.116405  -0.102398  -0.000554  -0.367179        2
# 9461    0.046121   0.177640  -0.000273   0.246818        1
# ...          ...        ...        ...        ...      ...
# 16420  -0.205903   0.062415  -0.000498  -0.255213        2
# 38567  -0.099982   0.250719  -0.001089  -0.073793        3
# 17120   0.170886   0.054296  -0.000290   0.079194        2
# 27851   0.247882  -0.196718   0.000304  -0.000555        0
# 21952   0.059492  -0.245723   0.000059  -0.076857        0
#
# [50000 rows x 10 columns]>

# %%
#Assigning X and Y parameter for testing 40Hz

dataset_test_40 = test_40.values
X_test_40 = dataset_test_40[:,0:9]
print(X_test_40)

y_test_40= dataset_test_40[:,9]
print(y_test_40)
# Out:
# [[ 5.640000e-02  2.612366e+00 -8.866247e+00 ...  2.205720e-01
#    9.320000e-05  2.152160e-01]
#  [ 5.094650e+00  6.031629e+00 -6.319045e+00 ... -2.083760e-01
#   -4.470000e-04  1.382000e-02]
#  [ 1.400000e-01 -3.388524e+00 -5.871800e-02 ...  3.883200e-02
#   -5.400000e-04  1.009360e-01]
#  ...
#  [ 3.560000e-01 -2.792319e+00 -2.122779e+00 ...  5.429600e-02
#   -2.900000e-04  7.919400e-02]
#  [ 3.092550e+00  6.863611e+00 -5.009591e+00 ... -1.967180e-01
#    3.040000e-04 -5.550000e-04]
#  [ 9.760000e-02 -3.856391e+00 -2.906978e+00 ... -2.457230e-01
#    5.870000e-05 -7.685700e-02]]
# [0. 4. 4. ... 2. 0. 0.]

# %%
# Testing mix data from different rotational speeds of 10Hz, 15Hz, 20Hz, 25Hz, 30Hz with 200 dataset row per fault
# for each rotational speed

test_mix= pd.read_csv(r'D:\Acads\BTP\Train\Mix_test_10_15_20_25_30.csv')
test_mix.head
test_mix= test_mix.sample(frac=1)
test_mix.head
# Out:
# <bound method NDFrame.head of       X_Value  Acceleration  Acceleration_0  Acceleration_1   Voltage  \
# 201   0.00010      0.767451        0.928313       -0.609862  0.193713
# 1821  0.33655     -0.905486        0.068851       -0.702617 -0.043270
# 2498  0.99090     -2.962822       -0.458368       -1.492317 -0.146686
# 3198  0.04995     -2.365512       -4.791656       -0.557052 -0.023397
# 2263  0.98960      0.678696        2.277424       -0.735945  0.218469
# ...       ...           ...             ...             ...       ...
# 3240  0.05205     -1.648468       -1.399480       -2.350388  0.056029
# 446   0.05235     -0.849922       -0.125388       -0.526665  0.175490
# 4387  0.50800    -11.522474       -6.219838       -4.512780 -0.208412
# 2301  0.99150     -2.758760       -1.949782       -1.858678  0.183825
# 3904  0.50485     -3.339476        0.601595        1.148552  0.134296
#
#       Voltage_0  Voltage_1  Voltage_2  Voltage_3  Identity
# 201   -0.029580  -0.165588   0.001368  -0.047367         2
# 1821   0.218044  -0.175815  -0.000400   0.020943         2
# 2498   0.201774  -0.055848   0.000123   0.037119         0
# 3198   0.215496  -0.194437  -0.001460  -0.001950         3
# 2263  -0.195385  -0.023125   0.003820   0.112800         3
# ...         ...        ...        ...        ...       ...
# 3240   0.172114  -0.230031  -0.001288   0.213386         3
# 446    0.021653  -0.200097   0.000033   0.189325         0
# 4387   0.025254   0.183497  -0.000530  -0.024454         2
# 2301  -0.224824   0.042605   0.003672  -0.026713         3
# 3904  -0.239909   0.105996  -0.001066   0.175391         3
#
# [4598 rows x 10 columns]>

# %%
#Assigning X and Y parameter for Mix testing  

dataset_test_mix = test_mix.values
X_test_mix = dataset_test_mix[:,0:9]
print(X_test_mix)

y_test_mix= dataset_test_mix[:,9]
print(y_test_mix)
# Out:
# [[ 1.0000000e-04  7.6745100e-01  9.2831300e-01 ... -1.6558800e-01
#    1.3680000e-03 -4.7367000e-02]
#  [ 3.3655000e-01 -9.0548600e-01  6.8851000e-02 ... -1.7581500e-01
#   -4.0000000e-04  2.0943000e-02]
#  [ 9.9090000e-01 -2.9628220e+00 -4.5836800e-01 ... -5.5848000e-02
#    1.2300000e-04  3.7119000e-02]
#  ...
#  [ 5.0800000e-01 -1.1522474e+01 -6.2198380e+00 ...  1.8349700e-01
#   -5.3000000e-04 -2.4454000e-02]
#  [ 9.9150000e-01 -2.7587600e+00 -1.9497820e+00 ...  4.2605000e-02
#    3.6720000e-03 -2.6713000e-02]
#  [ 5.0485000e-01 -3.3394760e+00  6.0159500e-01 ...  1.0599600e-01
#   -1.0660000e-03  1.7539100e-01]]
# [2. 2. 0. ... 2. 3. 3.]

# %%
import numpy as np
#Predicting with 30Hz training
predictions_15 = rf_30.predict(X_test_15)
errors_15 = abs(predictions_15 - y_test_15)
print('Mean Absolute Error 15Hz with 30Hz:', round(np.mean(errors_15), 3), 'degrees.')

accuracy = 100 - np.mean(errors_15)
print('Accuracy:', round(accuracy, 3), '%.')
# Out:
# Mean Absolute Error 15Hz with 30Hz: 0.612 degrees.
# Accuracy: 99.388 %.

# %%
predictions_20 = rf_30.predict(X_test_20)
errors_20 = abs(predictions_20 - y_test_20)
print('Mean Absolute Error 20Hz with 30Hz:', round(np.mean(errors_20), 3), 'degrees.')

accuracy = 100 - np.mean(errors_20)
print('Accuracy:', round(accuracy, 3), '%.')
# Out:
# Mean Absolute Error 20Hz with 30Hz: 0.276 degrees.
# Accuracy: 99.724 %.

# %%
predictions_30 = rf_30.predict(X_test_30)
errors_30 = abs(predictions_30 - y_test_30)
print('Mean Absolute Error 30Hz with 30Hz:', round(np.mean(errors_30), 3), 'degrees.')

accuracy = 100 - np.mean(errors_30)
print('Accuracy:', round(accuracy, 3), '%.')
# Out:
# Mean Absolute Error 30Hz with 30Hz: 0.035 degrees.
# Accuracy: 99.965 %.

# %%
predictions_40 = rf_30.predict(X_test_40)
errors_40 = abs(predictions_40 - y_test_40)
print('Mean Absolute Error 40Hz with 30Hz:', round(np.mean(errors_40), 3), 'degrees.')

accuracy = 100 - np.mean(errors_40)
print('Accuracy:', round(accuracy, 3), '%.')
# Out:
# Mean Absolute Error 40Hz with 30Hz: 0.192 degrees.
# Accuracy: 99.808 %.

# %%
predictions_mix = rf_30.predict(X_test_mix)
errors_mix = abs(predictions_mix - y_test_mix)
print('Mean Absolute Error Mix Dataset with 30Hz:', round(np.mean(errors_mix), 3), 'degrees.')

accuracy = 100 - np.mean(errors_mix)
print('Accuracy:', round(accuracy, 3), '%.')
# Out:
# Mean Absolute Error Mix Dataset with 30Hz: 0.2 degrees.
# Accuracy: 99.705 %.

# %%
#Predicting with 20Hz training
predictions_15 = rf_20.predict(X_test_15)
errors_15 = abs(predictions_15 - y_test_15)
print('Mean Absolute Error 15Hz with 20Hz:', round(np.mean(errors_15), 3), 'degrees.')

accuracy = 100 - np.mean(errors_15)
print('Accuracy:', round(accuracy, 3), '%.')
# Out:
# Mean Absolute Error 15Hz with 20Hz: 0.429 degrees.
# Accuracy: 99.571 %.

# %%
predictions_20 = rf_20.predict(X_test_20)
errors_20 = abs(predictions_20 - y_test_20)
print('Mean Absolute Error 20Hz with 20Hz:', round(np.mean(errors_20), 3), 'degrees.')

accuracy = 100 - np.mean(errors_20)
print('Accuracy:', round(accuracy, 3), '%.')
# Out:
# Mean Absolute Error 20Hz with 20Hz: 0.027 degrees.
# Accuracy: 99.973 %.

# %%
predictions_30 = rf_20.predict(X_test_30)
errors_30 = abs(predictions_30 - y_test_30)
print('Mean Absolute Error 20Hz with 30Hz:', round(np.mean(errors_30), 3), 'degrees.')

accuracy = 100 - np.mean(errors_30)
print('Accuracy:', round(accuracy, 3), '%.')
# Out:
# Mean Absolute Error 20Hz with 30Hz: 0.272 degrees.
# Accuracy: 99.728 %.

# %%
predictions_40 = rf_20.predict(X_test_40)
errors_40 = abs(predictions_40 - y_test_40)
print('Mean Absolute Error 40Hz with 30Hz:', round(np.mean(errors_40), 3), 'degrees.')

accuracy = 100 - np.mean(errors_40)
print('Accuracy:', round(accuracy, 3), '%.')
# Out:
# Mean Absolute Error 40Hz with 30Hz: 0.496 degrees.
# Accuracy: 99.504 %.

# %%
predictions_mix = rf_20.predict(X_test_mix)
errors_mix = abs(predictions_mix - y_test_mix)
print('Mean Absolute Error Mix Dataset with 30Hz:', round(np.mean(errors_mix), 3), 'degrees.')

accuracy = 100 - np.mean(errors_mix)
print('Accuracy:', round(accuracy, 3), '%.')
# Out:
# Mean Absolute Error Mix Dataset with 30Hz: 0.029 degrees.
# Accuracy: 99.724 %.

# %% [markdown]
# ## Results testing different datasets against 30Hz trained model
# ### 15Hz : 0.612 Mean Absolute error
# ### 20Hz : 0.276 Mean Absolute error
# ### 30Hz : 0.035 Mean Absolute error
# ### 40Hz:  0.192 MAE
# ### Mix speed:

# %% [markdown]
# ## Results testing different datasets against 20Hz trained model
# ### 15Hz : 0.429 Mean Absolute error
# ### 20Hz : 0.027 Mean Absolute error
# ### 30Hz : 0.272 Mean Absolute error
# ### 40Hz : 0.496 MAE
# ### Mix speed:

# %%
#Predicting with 40Hz training
predictions_15 = rf_40.predict(X_test_15)
errors_15 = abs(predictions_15 - y_test_15)
print('Mean Absolute Error 15Hz with 40Hz:', round(np.mean(errors_15), 3), 'degrees.')

accuracy = 100 - np.mean(errors_15)
print('Accuracy:', round(accuracy, 3), '%.')
# Out:
# Mean Absolute Error 15Hz with 40Hz: 0.938 degrees.
# Accuracy: 99.062 %.

# %%
predictions_20 = rf_40.predict(X_test_20)
errors_20 = abs(predictions_20 - y_test_20)
print('Mean Absolute Error 20Hz with 40Hz:', round(np.mean(errors_20), 3), 'degrees.')

accuracy = 100 - np.mean(errors_20)
print('Accuracy:', round(accuracy, 3), '%.')
# Out:
# Mean Absolute Error 20Hz with 40Hz: 0.802 degrees.
# Accuracy: 99.198 %.

# %%
predictions_30 = rf_40.predict(X_test_30)
errors_30 = abs(predictions_30 - y_test_30)
print('Mean Absolute Error 20Hz with 40Hz:', round(np.mean(errors_30), 3), 'degrees.')

accuracy = 100 - np.mean(errors_30)
print('Accuracy:', round(accuracy, 3), '%.')
# Out:
# Mean Absolute Error 20Hz with 40Hz: 0.732 degrees.
# Accuracy: 99.268 %.

# %%
predictions_40 = rf_40.predict(X_test_40)
errors_40 = abs(predictions_40 - y_test_40)
print('Mean Absolute Error 40Hz with 40Hz:', round(np.mean(errors_40), 3), 'degrees.')

accuracy = 100 - np.mean(errors_40)
print('Accuracy:', round(accuracy, 3), '%.')
# Out:
# Mean Absolute Error 40Hz with 40Hz: 0.0 degrees.
# Accuracy: 100.0 %.

# %% [markdown]
# ## Results testing different datasets against 40Hz trained model
# ### 15Hz : 0.938 Mean Absolute error
# ### 20Hz : 0.802 Mean Absolute error
# ### 30Hz : 0.732 Mean Absolute error
# ### Mix speed:
